# %% [markdown]
# # 02 - Mapeamento de Variáveis de Processo
#
# **Projeto:** Estação de Reabastecimento de Hidrogênio - SCADA Core
# **Etapa:** 01 - Lógica e Estruturação
#
# Este documento apresenta o mapeamento sistemático de instrumentos, atuadores e variáveis físicas divididos nos setores da planta (Armazenamento, Condicionamento e Dispensador), acompanhados de suas respectivas **proposições lógicas** para processamento em sistema SCADA e intertravamentos de segurança (norma ISA-5.1).

# %%
import pandas as pd

# Tabela unificada de Proposições Lógicas e Variáveis do Projeto baseado na norma ISA-5.1
proposicoes_h2 = [
    # Setor 100: Armazenamento de Hidrogênio
    {"Setor": "100 - Armazenamento", "Tag": "PT-101", "Variável Física": "Pressão tanque baixa pressão", "Proposição": "p_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "PT-104", "Variável Física": "Pressão desejada tanque baixa", "Proposição": "p_{1,4}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "TT-101", "Variável Física": "Temp. tanque baixa pressão", "Proposição": "t_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "AT-101", "Variável Física": "Detector de Gás H2 (Baixa)", "Proposição": "g_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "PSV-101", "Variável Física": "Válvula de Alívio (Baixa)", "Proposição": "r_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "XV-101", "Variável Física": "Válvula Corte Rápido (Baixa)", "Proposição": "v_{1,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "SL-101", "Variável Física": "Sinalizador / Luz (Baixa)", "Proposição": "s_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    
    {"Setor": "100 - Armazenamento", "Tag": "PT-102", "Variável Física": "Pressão tanque média pressão", "Proposição": "p_{1,2}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "PT-105", "Variável Física": "Pressão desejada tanque média", "Proposição": "p_{1,5}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "TT-102", "Variável Física": "Temp. tanque média pressão", "Proposição": "t_{1,2}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "AT-102", "Variável Física": "Detector de Gás H2 (Média)", "Proposição": "g_{1,2}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "PSV-102", "Variável Física": "Válvula de Alívio (Média)", "Proposição": "r_{1,2}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "XV-102", "Variável Física": "Válvula Corte Rápido (Média)", "Proposição": "v_{1,2}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "SL-102", "Variável Física": "Sinalizador / Luz (Média)", "Proposição": "s_{1,2}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},

    {"Setor": "100 - Armazenamento", "Tag": "PT-103", "Variável Física": "Pressão tanque alta pressão", "Proposição": "p_{1,3}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "PT-106", "Variável Física": "Pressão desejada tanque alta", "Proposição": "p_{1,6}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "TT-103", "Variável Física": "Temp. tanque alta pressão", "Proposição": "t_{1,3}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "AT-103", "Variável Física": "Detector de Gás H2 (Alta)", "Proposição": "g_{1,3}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "PSV-103", "Variável Física": "Válvula de Alívio (Alta)", "Proposição": "r_{1,3}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "XV-103", "Variável Física": "Válvula Corte Rápido (Alta)", "Proposição": "v_{1,3}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "SL-103", "Variável Física": "Sinalizador / Luz (Alta)", "Proposição": "s_{1,3}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    
    {"Setor": "100 - Armazenamento", "Tag": "XV-104", "Variável Física": "Seleção de Tanque (Direcional)", "Proposição": "v_{1,4}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "YV-104A", "Variável Física": "Bobina Solenoide A (Baixa)", "Proposição": "y_{1,4a}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "YV-104B", "Variável Física": "Bobina Solenoide B (Alta)", "Proposição": "y_{1,4b}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "ALM-101", "Variável Física": "Alarme Geral / Buzzer", "Proposição": "a_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "100 - Armazenamento", "Tag": "ESD-100", "Variável Física": "Parada de Emergência Manual", "Proposição": "e_{1,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},

    # Setor 200: Condicionamento (Pré-resfriamento)
    {"Setor": "200 - Condicionamento", "Tag": "TT-201", "Variável Física": "Temp. Saída Pré-resfriador", "Proposição": "t_{2,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "200 - Condicionamento", "Tag": "PT-201", "Variável Física": "Pressão do Buffer", "Proposição": "p_{2,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "200 - Condicionamento", "Tag": "M-201",  "Variável Física": "Contator Motor Chiller", "Proposição": "m_{2,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "200 - Condicionamento", "Tag": "XV-201", "Variável Física": "Válvula Entrada Chiller", "Proposição": "v_{2,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},

    # Setor 300: Dispensador e Transferência
    {"Setor": "300 - Dispensador", "Tag": "HS-301", "Variável Física": "Início de Abastecimento", "Proposição": "h_{3,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "300 - Dispensador", "Tag": "COM-301", "Variável Física": "Comunicação IR (J2799)", "Proposição": "c_{3,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "300 - Dispensador", "Tag": "BV-301", "Variável Física": "Válvula Ruptura (Breakaway)", "Proposição": "bv_{3,1}", "Valor Booleano": True, "Status": "CRÍTICO/ATIVO"},
    {"Setor": "300 - Dispensador", "Tag": "XV-301", "Variável Física": "Alimentação Bico Dispensador", "Proposição": "v_{3,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "300 - Dispensador", "Tag": "PT-301", "Variável Física": "Pressão no Nozzle (Veículo)", "Proposição": "p_{3,1}", "Valor Booleano": True,  "Status": "CRÍTICO/ATIVO"},
    {"Setor": "300 - Dispensador", "Tag": "TT-301", "Variável Física": "Temp. Recepção Veículo", "Proposição": "t_{3,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"},
    {"Setor": "300 - Dispensador", "Tag": "AT-301", "Variável Física": "Detector Gás (Dispensador)", "Proposição": "g_{3,1}", "Valor Booleano": False, "Status": "NORMAL/INATIVO"}
]

# Criando DataFrame
df_proposicoes = pd.DataFrame(proposicoes_h2)

# Configurando o Pandas para exibir todas as linhas sem truncar
pd.set_option('display.max_rows', None)
display(df_proposicoes)

# %% [markdown]
# ### Geração de Arquivos para o Sistema SCADA
# O bloco abaixo exporta a tabela estruturada em formato CSV, permitindo a integração direta das proposições lógicas com o ambiente de programação do CLP.

# %%
df_proposicoes.to_csv('proposicoes_logicas_H2.csv', index=False, encoding="utf-8")
print('Tabela de proposições lógicas estruturada e exportada com sucesso!')
